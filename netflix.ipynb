# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\HASOUB\Downloads\mymoviedb.csv")
data
# Out:
#      Release_Date                                 Title  \
# 0      12/15/2021               Spider-Man: No Way Home
# 1        3/1/2022                            The Batman
# 2       2/25/2022                               No Exit
# 3      11/24/2021                               Encanto
# 4      12/22/2021                        The King's Man
# ...           ...                                   ...
# 9821   10/15/1973                              Badlands
# 9822    10/1/2020                      Violent Delights
# 9823     5/6/2016                          The Offering
# 9824    3/31/2021  The United States vs. Billie Holiday
# 9825    9/23/1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
data.head()
# Out:
#   Release_Date                    Title  \
# 0   12/15/2021  Spider-Man: No Way Home
# 1     3/1/2022               The Batman
# 2    2/25/2022                  No Exit
# 3   11/24/2021                  Encanto
# 4   12/22/2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9826 entries, 0 to 9825
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   object
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   int64
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.0+ KB

# %%
data.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9826.000000   9826.000000   9826.000000
# mean     40.323951   1392.943721      6.439467
# std     108.879332   2611.303856      1.129797
# min      13.354000      0.000000      0.000000
# 25%      16.128250    146.000000      5.900000
# 50%      21.195000    444.000000      6.500000
# 75%      35.179250   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
data.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Overview             0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Poster_Url           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Genre']
# Out:
# 0       Action, Adventure, Science Fiction
# 1                 Crime, Mystery, Thriller
# 2                                 Thriller
# 3       Animation, Comedy, Family, Fantasy
# 4         Action, Adventure, Thriller, War
#                        ...
# 9821                          Drama, Crime
# 9822                                Horror
# 9823             Mystery, Thriller, Horror
# 9824                 Music, Drama, History
# 9825           War, Drama, Science Fiction
# Name: Genre, Length: 9826, dtype: object

# %%
data.head()
# Out:
#   Release_Date                    Title  \
# 0   12/15/2021  Spider-Man: No Way Home
# 1     3/1/2022               The Batman
# 2    2/25/2022                  No Exit
# 3   11/24/2021                  Encanto
# 4   12/22/2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %% [raw]
#  To change the datatype of the release_date column

# %%
data['Release_Date'] = pd.to_datetime(data['Release_Date'])
data['Release_Date']
# Out:
# 0      2021-12-15
# 1      2022-03-01
# 2      2022-02-25
# 3      2021-11-24
# 4      2021-12-22
#           ...
# 9821   1973-10-15
# 9822   2020-10-01
# 9823   2016-05-06
# 9824   2021-03-31
# 9825   1984-09-23
# Name: Release_Date, Length: 9826, dtype: datetime64[ns]

# %%
data.head(5)
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9826 entries, 0 to 9825
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   datetime64[ns]
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   int64
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 691.0+ KB

# %%
data['Release_Date'] = data['Release_Date'].dt.year

data['Release_Date']
# Out:
# 0       2021
# 1       2022
# 2       2022
# 3       2021
# 4       2021
#         ...
# 9821    1973
# 9822    2020
# 9823    2016
# 9824    2021
# 9825    1984
# Name: Release_Date, Length: 9826, dtype: int32

# %%
data.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %% [markdown]
# # dropping the column

# %%
col = ['Overview','Original_Language','Poster_Url']
data.drop(col,axis=1,inplace=True)

# %%
def catigorize_col(data,col,labels):
    edges = [data[col].describe()['min'],
             data[col].describe()['25%'],
             data[col].describe()['50%'],
             data[col].describe()['75%'],
             data[col].describe()['max']]
    
    data[col] = pd.cut(data[col],edges,labels = labels,duplicates = 'drop')
    return data
    
labels = ['not_populalar','below_avg','average','popular']

catigorize_col(data, 'Vote_Average', labels)

data['Vote_Average'].unique()
# Out:
# ['popular', 'below_avg', 'average', 'not_populalar', NaN]
# Categories (4, object): ['not_populalar' < 'below_avg' < 'average' < 'popular']

# %%
data.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 1          2022               The Batman    3827.658        1151      popular
# 2          2022                  No Exit    2618.087         122    below_avg
# 3          2021                  Encanto    2402.201        5076      popular
# 4          2021           The King's Man    1895.511        1793      average
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
data['Vote_Average'].value_counts()
# Out:
# Vote_Average
# not_populalar    2467
# popular          2450
# average          2411
# below_avg        2398
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 1          2022               The Batman    3827.658        1151      popular
# 2          2022                  No Exit    2618.087         122    below_avg
# 3          2021                  Encanto    2402.201        5076      popular
# 4          2021           The King's Man    1895.511        1793      average
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %% [markdown]
# # we have split genre in a list than explode dataframe to have only one genre per row for each movie

# %%
data['Genre'] = data['Genre'].str.split(', ')
data = data.explode('Genre').reset_index(drop=True)
data.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 1          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 2          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 3          2022               The Batman    3827.658        1151      popular
# 4          2022               The Batman    3827.658        1151      popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %% [markdown]
# # casting column into category

# %%
data['Genre'] = data['Genre'].astype('category')
data['Genre'].dtype
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
data.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 1          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 2          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 3          2022               The Batman    3827.658        1151      popular
# 4          2022               The Batman    3827.658        1151      popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  25551 non-null  int32
#  1   Title         25551 non-null  object
#  2   Popularity    25551 non-null  float64
#  3   Vote_Count    25551 non-null  int64
#  4   Vote_Average  25551 non-null  category
#  5   Genre         25551 non-null  category
# dtypes: category(2), float64(1), int32(1), int64(1), object(1)
# memory usage: 749.6+ KB

# %% [markdown]
# # Data Visualization

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # What is the most frequent genre of movie released on netflix?

# %%
sns.catplot(y = 'Genre',data=data,kind = 'count',order = data['Genre'].value_counts().index,color='r')
plt.title('Genre distribution')
plt.show()

# %% [markdown]
# # Which has highest votes in vote avg column?

# %%
sns.catplot(y='Vote_Average',data=data,kind='count',order=data['Vote_Average'].value_counts().index,color='r')
plt.title('Vote avg column distribution')
plt.show()

# %% [markdown]
# # What movie got the highest popularity? what's its genre?

# %%
data[data['Popularity'] == data['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 1          2021  Spider-Man: No Way Home    5083.954        8940      popular
# 2          2021  Spider-Man: No Way Home    5083.954        8940      popular
#
#              Genre  5083.954  3827.658  2618.087  2402.201  ...    13.367  \
# 0           Action  5083.954  5083.954  5083.954  5083.954  ...  5083.954
# 1        Adventure  5083.954  5083.954  5083.954  5083.954  ...  5083.954
# 2  Science Fiction  5083.954  5083.954  5083.954  5083.954  ...  5083.954
#
#      13.365    13.364     13.36    13.359    13.358    13.357    13.356  \
# 0  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954
# 1  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954
# 2  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954  5083.954
#
#      13.355    13.354
# 0  5083.954  5083.954
# ...

# %% [markdown]
# # What movie got the lowest popularity ? what's its genre?

# %%
data[data['Popularity'] == data['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25545          2021  The United States vs. Billie Holiday      13.354
# 25546          2021  The United States vs. Billie Holiday      13.354
# 25547          2021  The United States vs. Billie Holiday      13.354
# 25548          1984                               Threads      13.354
# 25549          1984                               Threads      13.354
# 25550          1984                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre  5083.954  3827.658  2618.087  \
# 25545         152      average            Music  5083.954  5083.954  5083.954
# 25546         152      average            Drama  5083.954  5083.954  5083.954
# 25547         152      average          History  5083.954  5083.954  5083.954
# 25548         186      popular              War  5083.954  5083.954  5083.954
# 25549         186      popular            Drama  5083.954  5083.954  5083.954
# ...

# %% [markdown]
# # Which year has the most filmmed movies?

# %%
data['Release_Date'].hist()
plt.title('year distribution')
plt.show()

# %%
Conclusion 
Q1: what is the most frequent genre in the dataset ?
Drama genre is the most frequent in our dataset 

Q2: what genre has highest votes ?
we have 25% of our dataset with popular vote (6520 rows)

Q3: what movie got the highest popularity ? what its genre?
spider-man  movie has the highest popularity in our dataset and its genre is Action ,adventure , science fiction 

Q4: what movie got the lowest popularity ? what its genre ?
the united state ,thread has the lowest rate in our dataset and its genre is music ,drama ,war,history,science fiction 

Q5 : Which year has the most filmmed movies?
year 2020 has the highest filmming rate in our dataset
